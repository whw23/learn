# %%
dict = {"a": 1, "b": 2, "c": ["3, 4", "5"], "d": {"e": 6, "f": 7}}
for key in dict:
    print(key, dict[key])
# Out:
# a 1
# b 2
# c ['3, 4', '5']
# d {'e': 6, 'f': 7}

# %%
dict["d"]
# Out:
# {'e': 6, 'f': 7}

# %%
# 判断键是否存在
if "a" in dict:
    print("Key exists in the dictionary.")
# Out:
# Key 'f' exists in the dictionary.
